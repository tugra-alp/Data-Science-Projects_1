# %% [markdown]
# # End-to-End Deployment of Zomato Restaurant Ratings
#
# ## 2-) MODELLING PART

# %%
import numpy as np 
import pandas as pd 

from pycaret.regression import *

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
data = pd.read_csv('Final_Zomato.csv')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.head() # rate is our target variable.
# Out:
#    online_order  book_table  rate  votes  location  rest_type  cuisines  \
# 0             1           1   4.1    775         1         20      1386
# 1             1           0   4.1    787         1         20       594
# 2             1           0   3.8    918         1         16       484
# 3             0           0   3.7     88         1         62      1587
# 4             0           0   3.8    166         4         20      1406
#
#     cost  menu_item
# 0  800.0       5047
# 1  800.0       5047
# 2  800.0       5047
# 3  300.0       5047
# 4  600.0       5047

# %%
X = data.drop('rate',axis=1)
y = data['rate']

# %% [markdown]
# #### Auto-ML with Pycaret
# - The reason that using Pycaret module ,I want to see which model can fit better on dataset.
# - This split is for Pycaret, thats what Pycaret wants

# %%
train, test = train_test_split(data, test_size = .3, random_state=1)

# %% [markdown]
# ##### Let's create regression object

# %%
reg = setup(data=train, target = 'rate',
            fold_strategy= 'kfold',
            fold =10,
            silent = True
           )
# Out:
# <style  type="text/css" >
# </style><table id="T_60019_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60019_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_60019_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_60019_row0_col1" class="data row0 col1" >4512</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_60019_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_60019_row1_col1" class="data row1 col1" >rate</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_60019_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_60019_row2_col1" class="data row2 col1" >(16273, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_60019_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_60019_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_60019_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_60019_row4_col1" class="data row4 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_60019_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_60019_row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_60019_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_60019_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_60019_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_60019_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_60019_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_60019_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_60019_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_60019_row9_col1" class="data row9 col1" >(11391, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_60019_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_60019_row10_col1" class="data row10 col1" >(4882, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_60019_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_60019_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_60019_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_60019_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_60019_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_60019_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_60019_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_60019_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_60019_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_60019_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_60019_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_60019_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_60019_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_60019_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_60019_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_60019_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_60019_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_60019_row19_col1" class="data row19 col1" >194a</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_60019_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_60019_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_60019_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_60019_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_60019_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_60019_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_60019_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_60019_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_60019_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_60019_row24_col0" class="data

# %%
best_model = compare_models(n_select = 3) # this will bring us best top 3 models with their parameter values (default)
# Out:
# <style  type="text/css" >
#     #T_5f9c5_ th {
#           text-align: left;
#     }#T_5f9c5_row0_col0,#T_5f9c5_row1_col0,#T_5f9c5_row1_col1,#T_5f9c5_row1_col2,#T_5f9c5_row1_col3,#T_5f9c5_row1_col4,#T_5f9c5_row1_col5,#T_5f9c5_row1_col6,#T_5f9c5_row2_col0,#T_5f9c5_row2_col1,#T_5f9c5_row2_col2,#T_5f9c5_row2_col3,#T_5f9c5_row2_col4,#T_5f9c5_row2_col5,#T_5f9c5_row2_col6,#T_5f9c5_row3_col0,#T_5f9c5_row3_col1,#T_5f9c5_row3_col2,#T_5f9c5_row3_col3,#T_5f9c5_row3_col4,#T_5
row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_5f9c5_row3_col1" class="data row3 col1" >0.1888</td>
#                         <td id="T_5f9c5_row3_col2" class="data row3 col2" >0.0739</td>
#                         <td id="T_5f9c5_row3_col3" class="data row3 col3" >0.2718</td>
#                         <td id="T_5f9c5_row3_col4" class="data row3 col4" >0.5945</td>
#                         <td id="T_5f9c5_row3_col5" class="data row3 col5" >0.0615</td>
#                         <td id="T_5f9c5_row3_col6" class="data row3 col6" >0.0533</td>
#                         <td id="T_5f9c5_row3_col7" class="data row3 col7" >0.2070</td>
#             </tr>
#             <tr>
#                         <th id="T_5f9c5_level0_row4" class="row_heading level0 row4" >knn</th>
#                         <td id="T_5f9c5_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#                         <td id="T_5f9c5_row4_col1" class="data row4 col1" >0.1985</td>
#                         <td id="T_5f9c5_row4_col2" class="data row4 col2" >0.0957</td>
#                         <td id="T_5f9c5_row4_col3" class="data row4 col3" >0.3091</td>
#                         <td id="T_5f9c5_row4_col4" class="data row4 col4" >0.4750</td>
#                         <td id="T_5f9c5_row4_col5" class="data row4 col5" >0.0692</td>
#                         <td id="T_5f9c5_row4_col6" class="data row4 col6" >0.0560</td>
#                         <td id="T_5f9c5_row4_col7" class="data row4 col7" >0.0760</td>
#             </tr>
#             <tr>
#                         <th id="T_5f9c5_level0_

# %%
best_model
# Out:
# [ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      max_samples=None, min_impurity_decrease=0.0,
#                      min_impurity_split=None, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=4512, verbose=0, warm_start=False),
#  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=4512, verbose=0, warm_start=False),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=4512, splitter='best')]

# %% [markdown]
# ### Model Selection with GridSearchCV and Sklearn

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= .3, random_state = 1)

# %%
def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'ExtraTreesRegressor' : {
            'model': ExtraTreesRegressor(random_state=1),
            'params': {
                'n_estimators': [120, 180, 250, 300],    
            }
        },
        'RandomForestRegressor': {
            'model': RandomForestRegressor(random_state=1),
            'params': {
                'n_estimators': [10, 100, 150, 200],
                'max_features' : ['auto', 'sqrt']
            }
        }
    }
    
    scores = []
    for algo_name, config in algos.items():
        model_selection =  GridSearchCV(config['model'], config['params'], cv=10, return_train_score=False)
        model_selection.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': model_selection.best_score_,
            'best_params': model_selection.best_params_
        })
         
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
outcome = find_best_model_using_gridsearchcv(X,y)

# %%
outcome # Best train R2 score is %87
# Out:
#                    model  best_score  \
# 0    ExtraTreesRegressor    0.877389
# 1  RandomForestRegressor    0.856764
#
#                                      best_params
# 0                          {'n_estimators': 300}
# 1  {'max_features': 'sqrt', 'n_estimators': 200}

# %% [markdown]
# #### Model Building with Extra Trees Regressiom

# %%
ET_model = ExtraTreesRegressor(n_estimators= 300, random_state=1)

# %%
ET_model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=300, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False)

# %%
ET_model.predict(X_test[:1])
# Out:
# array([3.69866667])

# %%
y_test[:1]
# Out:
# 18612    3.7
# Name: rate, dtype: float64

# %%
from sklearn.metrics import r2_score
y_pred=ET_model.predict(X_test)
r2_score(y_test,y_pred) # Test Score
# Out:
# 0.9332909033477896

# %% [markdown]
# ### Model Saving

# %%
import pickle 
# Saving model to disk
pickle.dump(ET_model, open('model.pkl','wb'))
model=pickle.load(open('model.pkl','rb'))
